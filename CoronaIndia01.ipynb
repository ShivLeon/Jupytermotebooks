# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datac=pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/CoronaIndia/covid19-corona-virus-india-dataset/patients_data.csv")

# %%
datac
# Out:
#        patient_number state_patient_number date_announced age_bracket gender  \
# 0                   1             KL-TS-P1     30/01/2020          20      F
# 1                   2             KL-AL-P1     02/02/2020         NaN    NaN
# 2                   3             KL-KS-P1     03/02/2020         NaN    NaN
# 3                   4                DL-P1     02/03/2020          45      M
# 4                   5                TS-P1     02/03/2020          24      M
# ...               ...                  ...            ...         ...    ...
# 12316           12318                  NaN     15/04/2020         NaN    NaN
# 12317           12319                  NaN     15/04/2020         NaN    NaN
# 12318           12320                  NaN     15/04/2020         NaN    NaN
# 12319           12321                  NaN     15/04/2020         NaN    NaN
# 12320           12322                  NaN     15/04/2020         NaN    NaN
#
# ...

# %%
datac["status_change_date"].unique()
# Out:
# array(['14/02/2020', '15/03/2020', '02/03/2020', '03/03/2020',
#        '29/03/2020', '04/03/2020', '05/03/2020', '07/03/2020',
#        '27/03/2020', '09/03/2020', '26/03/2020', '25/03/2020',
#        '20/03/2020', '03/04/2020', '10/03/2020', '24/03/2020',
#        '31/03/2020', '28/03/2020', '11/03/2020', '01/04/2020',
#        '12/03/2020', '13/03/2020', '23/03/2020', '01/03/2020',
#        '14/03/2020', '02/04/2020', '16/03/2020', '17/03/2020',
#        '18/03/2020', '06/04/2020', '30/03/2020', '05/04/2020',
#        '19/03/2020', '07/04/2020', '21/03/2020', '22/03/2020',
#        '12/04/2020', '04/04/2020', '11/04/2020', '13/04/2020', nan,
#        '08/04/2020', '09/04/2020', '10/04/2020', '14/04/2020',
#        '15/04/2020'], dtype=object)

# %%
datac["detected_state"].unique()
# Out:
# array(['Kerala', 'Delhi', 'Telangana', 'Rajasthan', 'Haryana',
#        'Uttar Pradesh', 'Ladakh', 'Tamil Nadu', 'Jammu and Kashmir',
#        'Karnataka', 'Maharashtra', 'Punjab', 'Andhra Pradesh',
#        'Uttarakhand', 'Odisha', 'Puducherry', 'West Bengal', 'Chandigarh',
#        'Chhattisgarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Goa',
#        'Andaman and Nicobar Islands', 'Jharkhand', 'Assam',
#        'Arunachal Pradesh', 'Dadra and Nagar Haveli', 'Tripura',
#        'Nagaland', 'Meghalaya'], dtype=object)

# %%
datac=datac.dropna()

# %%
plt.plot(datac['patient_number'])

# %%
import datetime
plt.figure()
fig,ax=plt.subplots(figsize=(16,6))
x=[datetime.datetime.strptime(d,"%d/%m/%Y").date() for d in datac["status_change_date"].unique()]
ax=plt.gca()
formatter=mdates.DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(formatter)
locator=mdates.DayLocator()
ax.xaxis.set_major_locator(locator)

plt.plot(x, datac['patient_number'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-542197f48514> in <module>
#       4 x=[datetime.datetime.strptime(d,"%d/%m/%Y").date() for d in datac["status_change_date"].unique()]
#       5 ax=plt.gca()
# ----> 6 formatter=mdates.DateFormatter("%Y-%m-%d")
#       7 ax.xaxis.set_major_formatter(formatter)
#       8 locator=mdates.DayLocator()
#
# NameError: name 'mdates' is not defined
