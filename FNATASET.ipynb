# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataf=pd.read_excel("C:/Users/SHIVLEON/Downloads/FNAT Result.xlsx", index_column="SN", sheet_name="ASET")

# %%
dataf
# Out:
#     Unnamed: 0 Unnamed: 1             Unnamed: 2   Unnamed: 3  \
# 0          NaN        NaN                    NaN          NaN
# 1          NaN        NaN                    NaN          NaN
# 2          NaN         SN           Student Name       Course
# 3          NaN        NaN                    CSE          NaN
# 4          NaN          1        Shivendra Yadav  BE / B.Tech
# 5          NaN          2           Tamanna baid  BE / B.Tech
# 6          NaN          3      Harshita Jhamnani  BE / B.Tech
# 7          NaN          4   Animesh Kumar Namdeo  BE / B.Tech
# 8          NaN          5          Sourav Biswas  BE / B.Tech
# 9          NaN          6         Manodeep Singh  BE / B.Tech
# 10         NaN          7   Kavya C. Ezhuthachan  BE / B.Tech
# 11         NaN          8          Ganesh Mishra  BE / B.Tech
# 12         NaN          9         Manjari sharma  BE / B.Tech
# 13         NaN         10             Aman Singh  BE / B.Tech
# ...

# %%
dataf1=dataf.copy(deep=True)

# %%
dataf1
# Out:
#     Unnamed: 0 Unnamed: 1             Unnamed: 2   Unnamed: 3  \
# 0          NaN        NaN                    NaN          NaN
# 1          NaN        NaN                    NaN          NaN
# 2          NaN         SN           Student Name       Course
# 3          NaN        NaN                    CSE          NaN
# 4          NaN          1        Shivendra Yadav  BE / B.Tech
# 5          NaN          2           Tamanna baid  BE / B.Tech
# 6          NaN          3      Harshita Jhamnani  BE / B.Tech
# 7          NaN          4   Animesh Kumar Namdeo  BE / B.Tech
# 8          NaN          5          Sourav Biswas  BE / B.Tech
# 9          NaN          6         Manodeep Singh  BE / B.Tech
# 10         NaN          7   Kavya C. Ezhuthachan  BE / B.Tech
# 11         NaN          8          Ganesh Mishra  BE / B.Tech
# 12         NaN          9         Manjari sharma  BE / B.Tech
# 13         NaN         10             Aman Singh  BE / B.Tech
# ...

# %%
dataf1.shape
# Out:
# (25, 8)

# %%
dataf1.isnull().sum()
# Out:
# Unnamed: 0    25
# Unnamed: 1     5
# Unnamed: 2     3
# Unnamed: 3     5
# Unnamed: 4     5
# Unnamed: 5     5
# Unnamed: 6     5
# Unnamed: 7     5
# dtype: int64

# %%
dataf1.dropna(axis=0, how="all")
# Out:
#     Unnamed: 0 Unnamed: 1             Unnamed: 2   Unnamed: 3  \
# 2          NaN         SN           Student Name       Course
# 3          NaN        NaN                    CSE          NaN
# 4          NaN          1        Shivendra Yadav  BE / B.Tech
# 5          NaN          2           Tamanna baid  BE / B.Tech
# 6          NaN          3      Harshita Jhamnani  BE / B.Tech
# 7          NaN          4   Animesh Kumar Namdeo  BE / B.Tech
# 8          NaN          5          Sourav Biswas  BE / B.Tech
# 9          NaN          6         Manodeep Singh  BE / B.Tech
# 10         NaN          7   Kavya C. Ezhuthachan  BE / B.Tech
# 11         NaN          8          Ganesh Mishra  BE / B.Tech
# 12         NaN          9         Manjari sharma  BE / B.Tech
# 13         NaN         10             Aman Singh  BE / B.Tech
# 14         NaN         11            Shiva Reddy  BE / B.Tech
# 16         NaN        NaN                  CIVIL          NaN
# ...

# %%
dataf1=dataf1.drop([0,1,2,3,15,16])

# %%
dataf1=dataf1.drop(["Unnamed: 0"], axis=1)

# %%
dataf1
# Out:
#    Unnamed: 1             Unnamed: 2   Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4           1        Shivendra Yadav  BE / B.Tech         30         13
# 5           2           Tamanna baid  BE / B.Tech         28         11
# 6           3      Harshita Jhamnani  BE / B.Tech         32         12
# 7           4   Animesh Kumar Namdeo  BE / B.Tech         18         11
# 8           5          Sourav Biswas  BE / B.Tech         26         14
# 9           6         Manodeep Singh  BE / B.Tech         30         10
# 10          7   Kavya C. Ezhuthachan  BE / B.Tech         33         13
# 11          8          Ganesh Mishra  BE / B.Tech         21          5
# 12          9         Manjari sharma  BE / B.Tech         22          9
# 13         10             Aman Singh  BE / B.Tech         31         13
# 14         11            Shiva Reddy  BE / B.Tech         23         10
# 17         12      KISHAN KUMAR SAHU  BE / B.Tech         16         10
# ...

# %%
dataf1.columns=["SNO","Name","Branch","total","Verbal","Quantative","Logical",]

# %%
dataf1
# Out:
#    SNO                   Name       Branch total Verbal Quantative Logical
# 4    1        Shivendra Yadav  BE / B.Tech    30     13          8       9
# 5    2           Tamanna baid  BE / B.Tech    28     11          6      11
# 6    3      Harshita Jhamnani  BE / B.Tech    32     12          8      12
# 7    4   Animesh Kumar Namdeo  BE / B.Tech    18     11          3       4
# 8    5          Sourav Biswas  BE / B.Tech    26     14          6       6
# 9    6         Manodeep Singh  BE / B.Tech    30     10          7      13
# 10   7   Kavya C. Ezhuthachan  BE / B.Tech    33     13         10      10
# 11   8          Ganesh Mishra  BE / B.Tech    21      5          8       8
# 12   9         Manjari sharma  BE / B.Tech    22      9          5       8
# 13  10             Aman Singh  BE / B.Tech    31     13         10       8
# 14  11            Shiva Reddy  BE / B.Tech    23     10          5       8
# ...

# %%
import seaborn as sns

# %%
f,ax=plt.subplots(1,1,figsize=(16,4))
g=sns.barplot(dataf1["Name"], dataf1["total"],palette="Set1")
g.set_title("FNAT TOTAL SCORE BTECH", fontweight="bold")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontweight="bold")
plt.show()

# %%
f,ax=plt.subplots(1,1,figsize=(16,4))
g=sns.barplot(dataf1["Name"], dataf1["Verbal"],palette="Set1")
g.set_title("FNAT Verbal SCORE BTECH")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
f,ax=plt.subplots(1,1,figsize=(16,4))
g=sns.barplot(dataf1["Name"], dataf1["Quantative"],palette="Set2")
g.set_title("FNAT Quantative SCORE BTECH")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
f,ax=plt.subplots(1,1,figsize=(16,4))
g=sns.barplot(dataf1["Name"], dataf1["Logical"],palette="Set1")
g.set_title("FNAT Logical Reasoning SCORE BTECH")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# lets make a Linear regression model for it

# %%
#checking the dependenices b/w total and the rest

# %%
plt.scatter(dataf1["total"],dataf1["Verbal"],color="green")

# %%
dataf1.plot("total","Verbal",style="*") #Another way of scatter

# %%
dataf1.plot("total","Quantative",style="o")

# %%
plt.scatter(dataf1["total"],dataf1["Logical"],color="red")

# %%
#Since all show some type of relation.... total is dependent on all the independent variables
#that are Verbal, Logical and Quantative

# %%
"""#Now let's start making the linear model
import statsmodels.api as s
total=dataf1["total"]
verbal=s.add_constant(dataf1["Verbal"])
quan=s.add_constant(dataf1["Quantative"])
logi=s.add_constant(dataf1["Logical"])

model=s.OLS(total,verbal)
result=model.fit()
result.summary()"""

# %%
"""#Now let's start making the linear model
from statsmodels.formula.api import ols
res=ols(formula="total ~ Verbal+Quantative+Logical", data=dataf1).fit()"""

# %%
#Now let's start making the linear model
x=dataf1["total"].values.reshape(-1,1)
y=dataf1["Verbal"].values.reshape(-1,1)
z=dataf1["Quantative"].values.reshape(-1,1)
w=dataf1["Logical"].values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
model=reg.fit(x,y)

# %%
model.intercept_[0]
# Out:
# 5.259458929621646

# %%
model2=reg.fit(x,z)

# %%
model2.intercept_[0]
# Out:
# -0.8602234855910575

# %%
model3=reg.fit(x,w)

# %%
model3.intercept_[0]
# Out:
# -4.399235444030576

# %%
plt.plot(x,model.intercept_[0]+model.coef_[0][0]*x)

# %%
from statsmodels.formula.api import ols
res=ols(formula="total ~ Quantative+Verbal+Logical", data=dataf1).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-3a47da7f5b38> in <module>
#       1 from statsmodels.formula.api import ols
# ----> 2 res=ols(formula="total ~ Quantative+Verbal+Logical", data=dataf1).fit()
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     175                              'columns that has shape {0}. This occurs when '
#     176                              'the variable converted to endog is non-numeric'
# --> 177                              ' (e.g., bool or str).'.format(endog.shape))
#     178         if drop_cols is not None and len(drop_cols) > 0:
#     179             cols = [x for x in exog.columns if x not in drop_cols]
#
# ...
