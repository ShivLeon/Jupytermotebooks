# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_drop_r = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/dropout-ratio-2012-2015.csv")
df_dross_enr = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/gross-enrollment-ratio-2013-2016.csv")
df_per_sch_comp = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/percentage-of-schools-with-comps-2013-2016.csv")
df_per_sch_ele = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/percentage-of-schools-with-electricity-2013-2016.csv")
df_per_sch_water = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/percentage-of-schools-with-water-facility-2013-2016.csv")
df_sch_boys_toi = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/schools-with-boys-toilet-2013-2016.csv")
df_sch_girls_toi = pd.read_csv("D:/Spyder/Data-Envelopment-Analysis-Excel/Data/Indian School Education Statistics/schools-with-girls-toilet-2013-2016.csv")

# %%
print("Dropout-ratio:\n")
print(df_drop_r.head(10), '\n')
print("Gross-enrollmenet:\n")
print(df_dross_enr.head(10), '\n')
print("School with Computers:\n")
print(df_per_sch_comp.head(10), '\n')
print("School with Water:\n")
print(df_per_sch_water.head(10), '\n')
print("School with Boys Toilet:\n")
print(df_sch_boys_toi.head(10), '\n')
print("School with Girls Toilet:\n")
print(df_sch_girls_toi.head(10), '\n')
# Out:
# Dropout-ratio:
#
#              State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0       A & N Islands  2012-13         0.83          0.51          0.68
# 1       A & N Islands  2013-14         1.35          1.06          1.21
# 2       A & N Islands  2014-15         0.47          0.55          0.51
# 3      Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4      Andhra Pradesh  2013-14         4.31          4.39          4.35
# 5      Andhra Pradesh  2014-15         6.57          6.89          6.72
# 6  Arunachal  Pradesh  2013-14        11.54         10.22         10.89
# 7   Arunachal Pradesh  2012-13        15.84         14.44         15.16
# 8   Arunachal Pradesh  2014-15        11.51         10.09         10.82
# 9               Assam  2012-13         7.02          5.46          6.24
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0     Uppe_r_Primary                1.09                1.23            5.57
# ...

# %%
df_drop_r.isnull().sum()
# Out:
# State_UT               0
# year                   0
# Primary_Boys           0
# Primary_Girls          0
# Primary_Total          0
# Upper Primary_Boys     0
# Upper Primary_Girls    0
# Upper Primary_Total    0
# Secondary _Boys        0
# Secondary _Girls       0
# Secondary _Total       0
# HrSecondary_Boys       0
# HrSecondary_Girls      0
# HrSecondary_Total      0
# dtype: int64

# %%
def basic_info(data):
    categorical = []
    numerical = []
    print("Size = ", data.size)
    print("Shape = ", data.shape)
    data.info()
    for i in data.columns:
        if data[i].dtype == object:
            categorical.append(i)
        else:
            numerical.append(i)
    return categorical, numerical

# %%
basic_info(df_drop_r)
# Out:
# Size =  1540
# Shape =  (110, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    object
#  3   Primary_Girls        110 non-null    object
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    object
#  6   Upper Primary_Girls  110 non-null    object
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    object
#  9   Secondary _Girls     110 non-null    object
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    object
#  12  HrSecondary_Girls    110 non-null    object
#  13  HrSecondary_Total    110 non-null    object
# dtypes: object(14)
# ...

# %%
d = {'NR': np.nan, '@': np.nan, 'Uppe_r_Primary': np.nan}

# %%
df_drop_r = df_drop_r.replace(d)

# %%
df_drop_r[~['State_UT', 'year']] = df_drop_r[~['State_UT', 'year']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3b001a1be13f> in <module>
# ----> 1 df_drop_r[~['State_UT', 'year']] = df_drop_r[~['State_UT', 'year']].apply(pd.to_numeric)
#
# TypeError: bad operand type for unary ~: 'list'

# %%
basic_info(df_drop_r)
